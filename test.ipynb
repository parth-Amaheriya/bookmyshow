# %%
import base64
strData= "..."

decoded_bytes = base64.b64decode(strData)

print(len(decoded_bytes))
# Out:
# 880

# %%
import requests

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'content-type': 'multipart/form-data; boundary=----WebKitFormBoundarycL0YumMxHSH5FjAp',
    'origin': 'https://in.bookmyshow.com',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://in.bookmyshow.com/',
    'sec-ch-ua': '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'true-client-ip': '45.114.65.131',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36',
    'x-advertiser-id': '1575077417613612585',
    'x-app-code': 'WEB',
    'x-bms-id': '1.756192986.1777355908019',
    'x-geohash': 'ts5',
    'x-latitude': '23.039568',
    'x-location-selection': 'manual',
    'x-longitude': '72.566005',
    'x-platform': 'WEB',
    'x-platform-code': 'WEB',
    'x-region-code': 'AHD',
    'x-region-slug': 'ahmedabad',
    'x-segments': '',
}

files = {
    'strAppCode': (None, 'WEB'),
    'lngTransactionIdentifier': (None, '0'),
    'strCommand': (None, 'GETSEATLAYOUT'),
    'strVenueCode': (None, 'PPAM'),
    'strParam1': (None, '31916'),
    'strParam2': (None, 'WEB'),
    'strParam3': (None, ''),
    'strParam4': (None, ''),
    'strParam5': (None, 'Y'),
    'strParam6': (None, 'Y'),
    'strParam7': (None, 'N'),
    'strParam8': (None, ''),
    'strParam9': (None, ''),
    'strParam10': (None, ''),
    'strFormat': (None, 'json'),
}

response = requests.post('https://services-in.bookmyshow.com/doTrans.aspx', headers=headers, files=files)
response.text
# Out:
# "#blnSuccess\nfalse\n#intException\n3\n#strException\nSomething's not right here. Please try again after a while. We appreciate your patience. (#-1500)\n#intExceptionEx\n-1500\n#strData\n-\n#END"

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import unpad

# ❗ YOU MUST FIND THESE FROM JS
key = b'YOUR_32_BYTE_KEY_HERE___________'
iv = b'1234567890123456'  # exactly 16 bytes
cipher = AES.new(key, AES.MODE_CBC, iv)

decrypted = cipher.decrypt(decoded_bytes)

try:
    decrypted = unpad(decrypted, AES.block_size)
except:
    pass

print(decrypted.decode('utf-8', errors='ignore'))
# Out:
# g[s~o9I6	Pm=Ϣ6!6tR,MkzwAv(ryOҮv]t.acmW~,!pуTƺ$~(X/,Do(gbk(EҖLh'3Rl,z⅙Bb$vF{ኁf˗rO uu*Qҁ!%Y_(63n-ͬnK"#
# #bfE,6;3ǚF=:Eݔ,)A'm]LG۰khc{k96ej+_~;"؉18g
# &2<#P8d`yG[Ɔ
# NkXw{)ŭ++_"5y1+КJgW-p3*9DݛBNM`E4ܪH0> 9q鲔[;爐u/+*[	qYk3N5bZ;c#<R$
# -g?OFzeY,F`~Jz
# &w*ID
# WYĒ?e}gXꛙ=ZR͹ĭ
# boO}L{phD>LRk'BlLu-9K^u8LF?=cfY׭4Ut2P)EHc6[_ ؛;
# oj	wWx+QW!\

# %%
import gzip
import io

try:
    with gzip.GzipFile(fileobj=io.BytesIO(decrypted)) as f:
        print(f.read().decode())
except:
    print("Not gzip")
# Out:
# Not gzip

# %%
import base64

s = "..."

data = base64.b64decode(s)
print(data[:50])
print(len(data))
# Out:
# b":q\x15\xfb0\x88\xad \xa1c\xd3\xd6b\xb6\x8b'_[\xd4\xa67\xd9\rKJ\xe9\x02,\x0b\xec\xc9\x07\xf6v<\xd6\x92\xf0\xc5\x02\xfd\xc4}\xde\x90C\xd1\xfc\xb1Y"
# 880

# %%
import base64, zlib, gzip, io

raw = base64.b64decode(s)

# zlib
try:
    print(zlib.decompress(raw))
except Exception as e:
    print("zlib failed:", e)

# gzip
try:
    print(gzip.decompress(raw))
except Exception as e:
    print("gzip failed:", e)
# Out:
# zlib failed: Error -3 while decompressing data: incorrect header check
# gzip failed: Not a gzipped file (b':q')

# %%
hex_string=raw.hex()

# %%
cipher_bytes = bytes.fromhex(hex_string)
print(len(cipher_bytes))
print(cipher_bytes[:32])
# Out:
# 880
# b":q\x15\xfb0\x88\xad \xa1c\xd3\xd6b\xb6\x8b'_[\xd4\xa67\xd9\rKJ\xe9\x02,\x0b\xec\xc9\x07"

# %%
data = bytes.fromhex(hex_string)
iv = data[:16]
ciphertext = data[16:]

print("iv:", iv.hex())
print("ciphertext length:", len(ciphertext))
print("ciphertext mod 16:", len(ciphertext) % 16)
# Out:
# iv: 3a7115fb3088ad20a163d3d662b68b27
# ciphertext length: 864
# ciphertext mod 16: 0
